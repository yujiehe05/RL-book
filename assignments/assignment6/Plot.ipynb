# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
alpha = np.linspace(0.1,1,1000)
r = 0.02
sigma = 0.04
mu = 0.07
z = (1000000*(1+r)*(1+r-mu)-(1+r-mu)/alpha)/((1+r-mu)**2+sigma**2)

# %%
plt.plot(alpha,z)
